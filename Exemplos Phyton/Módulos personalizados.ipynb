# %% [markdown]
# # Módulos personalizados

# %%
import utilitarios as ut
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e6791d32ecd7> in <module>()
# ----> 1 import utilitarios as ut
#
# ModuleNotFoundError: No module named 'utilitarios'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Nova seção

# %%
ut.soma(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-409cdcf4910e> in <module>()
# ----> 1 ut.soma(1, 2, 3)
#
# NameError: name 'ut' is not defined

# %%
ut.mult(3, 2, 2)
# Out:
# 12

# %%
ut.isPalindromo('abc')
# Out:
# False

# %%
ut.isPalindromo('abccba')
# Out:
# True

# %%
t = 'abccba'

# %%
t[::-1]
# Out:
# 'abccba'

# %%
t1 = 'abc'
t1[::-1]
# Out:
# 'cba'

# %%
ut.divisao(10,2)
# Out:
# 5.0
