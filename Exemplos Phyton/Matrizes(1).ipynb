# %% [markdown]
# # Matrizes

# %%
import numpy as np

# %%
matriz = np.array([[2, 3, 1], 
                   [4, 5, 7]])

# %%
matriz
# Out:
# array([[2, 3, 1],
#        [4, 5, 7]])

# %%
matriz.shape
# Out:
# (2, 3)

# %%
matriz[0]
# Out:
# array([2, 3, 1])

# %%
matriz[1]
# Out:
# array([4, 5, 7])

# %%
matriz[0][2]
# Out:
# 1

# %%
matriz[1][2]
# Out:
# 7

# %%
matriz.shape
# Out:
# (2, 3)

# %%
for i in range(matriz.shape[0]):
  print(matriz[i])
  for j in range(matriz.shape[1]):
    print(matriz[i][j])
# Out:
# [2 3 1]
# 2
# 3
# 1
# [4 5 7]
# 4
# 5
# 7
